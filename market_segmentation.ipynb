# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans
from sklearn import preprocessing

# %% [markdown]
# # load the data

# %%
raw_data = pd.read_csv('market_segmentation.csv')
raw_data
# Out:
#     Satisfaction  Loyalty
# 0              4    -1.33
# 1              6    -0.28
# 2              5    -0.99
# 3              7    -0.29
# 4              4     1.06
# 5              1    -1.66
# 6             10    -0.97
# 7              8    -0.32
# 8              8     1.02
# 9              8     0.68
# 10            10    -0.34
# 11             5     0.39
# 12             5    -1.69
# 13             2     0.67
# 14             7     0.27
# 15             9     1.36
# 16             8     1.38
# 17             7     1.36
# 18             7    -0.34
# 19             9     0.67
# 20            10     1.18
# 21             3    -1.69
# 22             4     1.04
# 23             3    -0.96
# 24             6     1.03
# 25             9    -0.99
# 26            10     0.37
# 27             9     0.03
# 28             3    -1.36
# 29             5     0.73

# %% [markdown]
# # plot the data

# %%
plt.scatter(raw_data['Satisfaction'], raw_data['Loyalty'])
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
plt.show()

# %% [markdown]
# # select the features

# %%
x = raw_data.copy()

# %% [markdown]
# # cluster the data

# %%
kmeans = KMeans(2)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
cluster_data = x.copy()
cluster_data['Cluster'] = kmeans.fit_predict(x)
cluster_data
# Out:
#     Satisfaction  Loyalty  Cluster
# 0              4    -1.33        0
# 1              6    -0.28        1
# 2              5    -0.99        0
# 3              7    -0.29        1
# 4              4     1.06        0
# 5              1    -1.66        0
# 6             10    -0.97        1
# 7              8    -0.32        1
# 8              8     1.02        1
# 9              8     0.68        1
# 10            10    -0.34        1
# 11             5     0.39        0
# 12             5    -1.69        0
# 13             2     0.67        0
# 14             7     0.27        1
# 15             9     1.36        1
# 16             8     1.38        1
# 17             7     1.36        1
# 18             7    -0.34        1
# 19             9     0.67        1
# 20            10     1.18        1
# 21             3    -1.69        0
# 22             4     1.04        0
# 23             3    -0.96        0
# 24             6     1.03        1
# 25             9    -0.99        1
# ...

# %% [markdown]
# # plot the clusters

# %%
plt.scatter(cluster_data['Satisfaction'], cluster_data['Loyalty'], c=cluster_data['Cluster'], cmap='rainbow')
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
plt.show()

# %% [markdown]
# # Standerdizing data

# %%
x_scaled = preprocessing.scale(x)
x_scaled
# Out:
# array([[-0.93138063, -1.3318111 ],
#        [-0.15523011, -0.28117124],
#        [-0.54330537, -0.99160391],
#        [ 0.23284516, -0.29117733],
#        [-0.93138063,  1.05964534],
#        [-2.09560642, -1.6620122 ],
#        [ 1.39707095, -0.97159172],
#        [ 0.62092042, -0.32119561],
#        [ 0.62092042,  1.01962097],
#        [ 0.62092042,  0.67941378],
#        [ 1.39707095, -0.3412078 ],
#        [-0.54330537,  0.38923705],
#        [-0.54330537, -1.69203048],
#        [-1.70753116,  0.66940768],
#        [ 0.23284516,  0.26916393],
#        [ 1.00899568,  1.35982816],
#        [ 0.62092042,  1.37984035],
#        [ 0.23284516,  1.35982816],
#        [ 0.23284516, -0.3412078 ],
#        [ 1.00899568,  0.66940768],
#        [ 1.39707095,  1.17971847],
#        [-1.31945589, -1.69203048],
#        [-0.93138063,  1.03963316],
#        [-1.31945589, -0.96158562],
#        [-0.15523011,  1.02962706],
#        [ 1.00899568, -0.99160391],
#        [ 1.39707095,  0.36922486],
# ...

# %% [markdown]
# # Elbow method

# %%
wcss = []
for i in range(1, 10):
    kmeans = KMeans(i)
    kmeans.fit(x_scaled)
    wcss.append(kmeans.inertia_)
wcss
# Out:
# [60.0,
#  30.35236058808774,
#  22.956419533106974,
#  10.24718180592842,
#  9.236213145874501,
#  6.66668837339082,
#  5.53886813154541,
#  4.519965019741716,
#  3.773115467885196]

# %%
num_of_features = range(1, 10)
plt.plot(num_of_features, wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
kmeans_new = KMeans(5)
kmeans_new.fit(x_scaled)
# Out:
# KMeans(n_clusters=5)

# %%
cluster_data_new = x.copy()
cluster_data_new['Cluster'] = kmeans_new.fit_predict(x_scaled)
cluster_data_new
# Out:
#     Satisfaction  Loyalty  Cluster
# 0              4    -1.33        0
# 1              6    -0.28        2
# 2              5    -0.99        0
# 3              7    -0.29        3
# 4              4     1.06        4
# 5              1    -1.66        0
# 6             10    -0.97        3
# 7              8    -0.32        3
# 8              8     1.02        1
# 9              8     0.68        1
# 10            10    -0.34        3
# 11             5     0.39        2
# 12             5    -1.69        0
# 13             2     0.67        4
# 14             7     0.27        2
# 15             9     1.36        1
# 16             8     1.38        1
# 17             7     1.36        1
# 18             7    -0.34        3
# 19             9     0.67        1
# 20            10     1.18        1
# 21             3    -1.69        0
# 22             4     1.04        4
# 23             3    -0.96        0
# 24             6     1.03        2
# 25             9    -0.99        3
# ...

# %%
plt.scatter(cluster_data_new['Satisfaction'], cluster_data_new['Loyalty'], c=cluster_data_new['Cluster'], cmap='rainbow')
plt.xlabel('Satisfaction')
plt.ylabel('Loyalty')
plt.show()
