# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %% [markdown]
# # Load the data

# %%
data = pd.read_csv('countries_exercise.csv')
data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %% [markdown]
# # Plot the data

# %%
plt.scatter(data['Longitude'], data['Latitude'])
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# # select the features

# %%
x = data.iloc[:, 1:3]
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %%
kmeans = KMeans(7)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=7)

# %% [markdown]
# # Get the cluster results

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([1, 0, 2, 1, 3, 3, 3, 2, 1, 3, 4, 2, 6, 2, 1, 6, 3, 3, 2, 3, 5, 5,
#        0, 3, 2, 1, 1, 3, 1, 3, 1, 1, 1, 1, 1, 0, 0, 2, 5, 3, 1, 0, 5, 5,
#        2, 5, 4, 1, 2, 5, 1, 1, 1, 1, 3, 3, 3, 3, 2, 1, 3, 1, 5, 1, 3, 2,
#        3, 3, 2, 3, 6, 1, 3, 3, 6, 5, 3, 3, 3, 5, 5, 5, 5, 5, 3, 1, 3, 1,
#        6, 1, 0, 2, 1, 3, 1, 3, 0, 3, 0, 0, 2, 3, 3, 3, 3, 3, 3, 1, 3, 3,
#        0, 0, 0, 2, 0, 0, 1, 1, 0, 3, 3, 0, 3, 5, 3, 1, 3, 0, 2, 3, 3, 3,
#        0, 1, 5, 3, 3, 2, 0, 1, 6, 3, 5, 3, 0, 3, 0, 6, 2, 5, 1, 2, 2, 0,
#        2, 6, 5, 6, 5, 1, 4, 3, 3, 0, 6, 6, 2, 0, 1, 4, 1, 0, 6, 6, 3, 1,
#        0, 3, 1, 3, 4, 2, 3, 0, 2, 5, 2, 2, 2, 5, 0, 1, 5, 6, 5, 1, 3, 2,
#        2, 1, 3, 5, 1, 3, 3, 3, 2, 1, 2, 3, 1, 5, 5, 0, 0, 0, 6, 4, 1, 3,
#        3, 0, 2, 2, 3, 1, 1, 0, 3, 1, 1, 1, 1, 0, 6, 4, 4, 2, 2, 2, 2],
#       dtype=int32)

# %% [markdown]
# # Create a copy of the data and add the cluster results to it

# %%
data_with_clusters = data.copy()
data_with_clusters['Cluster'] = identified_clusters
data_with_clusters
# Out:
#              name   Longitude   Latitude  Cluster
# 0           Aruba  -69.982677  12.520880        1
# 1     Afghanistan   66.004734  33.835231        0
# 2          Angola   17.537368 -12.293361        2
# 3        Anguilla  -63.064989  18.223959        1
# 4         Albania   20.049834  41.142450        3
# ..            ...         ...        ...      ...
# 236         Samoa -172.164851 -13.753243        4
# 237         Yemen   47.586762  15.909280        2
# 238  South Africa   25.083901 -29.000341        2
# 239        Zambia   27.774759 -13.458242        2
# 240      Zimbabwe   29.851441 -19.004204        2
#
# [241 rows x 4 columns]

# %% [markdown]
# # Plot the clusters

# %%
plt.scatter(data_with_clusters['Longitude'], data_with_clusters['Latitude'], c = data_with_clusters['Cluster'], cmap='rainbow')
plt.xlim(-180, 180)
plt.ylim(-90, 90)
plt.show()

# %% [markdown]
# # WCSS

# %%
unique_country_names = data["name"].unique()
print("Unique country names:", unique_country_names.size)
wcss = []
for i in range(1, unique_country_names.size):
    kmeans = KMeans(i)
    kmeans.fit(x)
    wcss.append(kmeans.inertia_)
wcss
# Out:
# Unique country names: 241
# [1413859.6798344273,
#  657012.0797586323,
#  325235.522370559,
#  256734.58387798426,
#  192316.54513979866,
#  154483.6966670732,
#  136948.21943455175,
#  119364.03973677359,
#  95235.82546889549,
#  79701.49811252729,
#  70631.11570954094,
#  65588.66221749055,
#  61150.40128325488,
#  57797.21970530357,
#  52767.52895211163,
#  52321.74840594996,
#  46453.36077611837,
#  43622.488545649845,
#  44996.7959564801,
#  39289.08663845929,
#  35411.933035882364,
#  32706.538318119296,
#  31984.84023767105,
#  30627.937189142023,
#  27805.526859201524,
#  27274.40384146066,
#  25740.476907810757,
#  22531.192814059097,
#  23436.87514906172,
#  21376.715912474574,
#  19744.41067588124,
#  18865.980849074786,
#  20293.044205133425,
#  17436.518346958357,
#  18493.873208344354,
#  16035.923577280213,
#  15154.63133590205,
#  14842.58820654262,
#  14023.420156039643,
#  14188.234569830804,
#  14111.290949044462,
#  13085.414686977425,
#  12809.868015654632,
# ...

# %%
plt.scatter(range(1, unique_country_names.size), wcss)
plt.plot(range(1, unique_country_names.size), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')
