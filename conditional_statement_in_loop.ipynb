# %%
for i in range(10):
    print(2 ** i, end=" ")
# Out:
# 1 2 4 8 16 32 64 128 256 512

# %%
for n in range(1, 11):
    if n % 2 == 0:
        print(f"{n} is even")
    else:
        print(f"{n} is odd")
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even
# 5 is odd
# 6 is even
# 7 is odd
# 8 is even
# 9 is odd
# 10 is even
