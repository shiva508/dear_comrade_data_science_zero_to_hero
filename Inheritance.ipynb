# %%
from attr import dataclass


class Mapping:
    def __init__(self, iterable):
        self.items_list = []
        self.__update(iterable)
    def update(self, iterable):
        for item in iterable:
            self.items_list.append(item)
    __update = update
mapping_object = Mapping([1, 2, 3])
mapping_object.items_list
# Out:
# [1, 2, 3]

# %%
from dataclasses import dataclass
@dataclass
class Employee:
    name:str
    dept:str
    age:int

employee_object = Employee("Shiva", "IT", 30)
employee_object.name, employee_object.dept, employee_object.age
# Out:
# ('Shiva', 'IT', 30)

# %%
def reverse(data):
    for index in range(len(data)-1, -1, -1):
        yield data[index]
for char in reverse("hello"):
    print(char)
# Out:
# o
# l
# l
# e
# h
