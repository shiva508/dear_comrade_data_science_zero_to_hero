# %%
def make_incrementor(base_number):
    return lambda increament_by: increament_by + base_number
lets_increment_by_5 = make_incrementor(5)
result = lets_increment_by_5(10)
print(result)
# Out:
# 15

# %%
pairs = [(4, 'four'),(1, 'one'), (2, 'two'), (3, 'three')]
pairs.sort(key=lambda pair: pair[0])
print(pairs)
# Out:
# [(1, 'one'), (2, 'two'), (3, 'three'), (4, 'four')]

# %%
fruits = ['apple', 'banana', 'cherry', 'date', 'apple']
print("Number of fruits in list:", fruits.count('apple'))
fruits.append("jack fruit")
print(f"Fruits in basket {fruits}")
# Out:
# Number of fruits in list: 2
# Fruites in basket ['apple', 'banana', 'cherry', 'date', 'apple', 'jack fruit']

# %% [markdown]
# # Using List as stack

# %%
stack = [1, 2, 3]
stack.append(4)
print(stack)
print(stack.pop())
print(stack)
# Out:
# [1, 2, 3, 4]
# 4
# [1, 2, 3]

# %% [markdown]
# # Using Lists as Queues

# %%
from collections import deque
queue = deque([1, 2, 3])
queue.append(4)
print(queue)
print(queue.popleft())
print(queue)
# Out:
# deque([1, 2, 3, 4])
# 1
# deque([2, 3, 4])
