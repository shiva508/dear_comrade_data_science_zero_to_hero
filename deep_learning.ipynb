# %% [markdown]
# # Deep Learning
# ## y = x*w + b

# %%
import numpy as np

# %%
x = np.array([2, 3])
w = np.array([1.2, -3])
xProductw = np.dot(x, w)
print(xProductw)
y = xProductw + np.array([7])
y
# Out:
# -6.6
# array([0.4])
