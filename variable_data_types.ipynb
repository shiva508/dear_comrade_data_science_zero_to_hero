# %% [markdown]
# # Create a variable with name x and a value of 10. Execute.
# # Tell the computer to show you the value of that variable without utilizing the print() function, similar to what you would do in Jupyter.

# %%
x = 10
x
# Out:
# 10

# %% [markdown]
# # Create a variable named x with the value 10. Then, use the print() function to display its value.

# %%
x = 10
print(x)
# Out:
# 10

# %% [markdown]
# # On the same line, create four new variables: a, b, c, and d, that are equal to 10, 20, 30, and 40, respectively

# %%
a=10; b=20; c=30; d=40

# %% [markdown]
# # On the same line, create four new variables: a, b, c, and d, that are equal to 10, 20, 30, and 40, respectively.
# # Tell the computer to show you the value corresponding to the variable b.
# # Do the same for d.

# %%
a = 10; b = 20; c = 30; d = 40
print(b)
print(d)
# Out:
# 20
# 40

# %% [markdown]
# # Number and Boolean Data Types

# %%
x = 4
type(x)
# Out:
# int

# %%
y = 3.5
type(y)
# Out:
# float

# %%
int(y)
# Out:
# 3

# %%
float(x)
# Out:
# 4.0

# %% [markdown]
# # Create a variable a equal to "True". Check its type.

# %%
a =  True
type(a)
# Out:
# bool

# %% [markdown]
# # Create a variable b equal to 99. Check its type.

# %%
b = 99
type(b)
# Out:
# int

# %% [markdown]
# # Check the type of the value 0.99.

# %%
type(0.99)
# Out:
# float

# %% [markdown]
# # Create a variable b equal to 99. Turn b into a float.
# # Consider using the print() function as a tool to help you solve this exercise.

# %%
b = 99
b_float = float(b)
print(b_float)
# Out:
# 99.0

# %% [markdown]
# # Turn 0.99 into an integer.

# %%
int(0.99)
# Out:
# 0

# %% [markdown]
# # String Data Types

# %%
shiva
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 shiva
#
# NameError: name 'shiva' is not defined

# %%
"Shiva"
# Out:
# 'Shiva'

# %%
'shiva'
# Out:
# 'shiva'

# %%
print("Shiva")
print('Shiva')
# Out:
# Shiva
# Shiva

# %%
roll_number = "21BCON001"
roll_number = 21
print("Roll Number:"+ str(roll_number))
# Out:
# Roll Number:21

# %% [markdown]
# # Assign the value of 100 to the variable m.
# # With the help of the variable m, write one line of code where the output after execution would be 100 days.
# # Hint: You could provide four answers to this question!

# %%
m = 100
print(str(m),"days")
# Out:
# 100 days

# %% [markdown]
# # Produce an output equal to It's cool, isn't it? .

# %%
print("It's cool, isn't it?")
# Out:
# It's cool, isn't it?

# %% [markdown]
# # Write a line of code to print Big Houses by passing each word as a separate argument to the print() function, ensuring there is a space between them in the output.

# %%
print("Big", "Houses")
# Out:
# Big Houses
