# %%
import numpy as np

# %%
int_range = 0.1
weights = np.random.uniform(low=-int_range, high=int_range, size=(2,1))
print("weights: ", weights)
bias = np.random.uniform(low=-int_range, high=int_range, size=1)
print("bias: ", bias)
# Out:
# weights:  [[-0.02286772]
#  [ 0.09079481]]
# bias:  [-0.04522698]
