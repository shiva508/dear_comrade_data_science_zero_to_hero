# %%
suspicious_email_text = f"""
From: SecureBank Support <support-update@secure-bank-net.com>
Subject: Urgent: Your Account Requires Immediate Verification

Dear Valued Customer,
We have detected unusual activity on your account. For your security, you must verify your identity immediately by clicking here: http://secure-bank-net.com/verify-now
Failure to do so within 24 hours will result in account suspension.
Thank you,
SecureBank Team
"""

# %%
system_prompt_generic = f"""
You are a senior Cybersecurity Analyst providing a formal threat assessment. Your tone is objective, cautious, and precise.

When analyzing a potential phishing email, do the following:
1.  State your overall assessment clearly (e.g., "High-Confidence Phishing Attempt").
2.  Do not speculate or use casual language.
3.  List the specific red flags you've identified as a bulleted list. For each flag, provide a brief explanation.
4.  Conclude with a clear, actionable recommendation for the end-user.
"""
user_prompt = f"""
Please analyze the following email and tell me if it's safe:
----
{suspicious_email_text}
----
"""

# %%
from ollama import Client
client = Client(
  host='http://localhost:11434',
  headers={'x-some-header': 'some-value'}
)
response = client.chat(model='llama3.1:8b', messages=[
    {
    'role': 'system',
    'content': system_prompt_generic,
  },
  {
    'role': 'user',
    'content': user_prompt,
  },
])
print(response.message)
# Out:
# role='assistant' content='**Threat Assessment:** High-Confidence Phishing Attempt\n\nI have identified the following specific red flags that indicate this email is a phishing attempt:\n\n*   **Suspicious sender address**: The email address "support-update@secure-bank-net.com" appears to be similar to the bank\'s name, but it has an additional "-update" and uses underscores instead of hyphens. This could be an attempt to make the email appear legitimate.\n*   **Urgent tone with no specific details**: The email creates a sense of urgency by stating that the account will be suspended if not verified within 24 hours, without providing any specific information about the unusual activity detected on the account.\n*   **Clickable link**: The email contains a clickable link "http://secure-bank-net.com/verify-now" that could potentially lead to a malicious website designed to steal sensitive information.\n*   **Lack of personalization**: Despite addressing the recipient as a "Valued Customer," the email does not contain any personalized details or references specific to the customer\'s account.\n\n**Recommendation:**\n\n*   Do not click on the link provided in the email and do not attempt to verify your account through it.\n*   Contact SecureBank directly using a verified phone number or contact method to report the suspicious email and ask for assistance with verifying your account.\n*   Be cautious of any similar emails that may appear in the future and verify their authenticity before taking any action.' thinking=None images=None tool_name=None tool_calls=None
