# %%
408 + 508
# Out:
# 916

# %%
508 -408
# Out:
# 100

# %%
408 * 408
# Out:
# 166464

# %%
15 / 3
# Out:
# 5.0

# %%
15 % 4
# Out:
# 3

# %%
5 ** 3
# Out:
# 125

# %% [markdown]
# # Add the integers 15 and 23.

# %%
15 + 23
# Out:
# 38

# %%
x = 5 ** 3

# %%
x == 125
# Out:
# True

# %%
"Friday"[1]

# %% [markdown]
# # Verify that 5 multiplied by 3 is less than or equal to 5 to the power of 3.

# %%
( 5 * 3) <= (5 ** 3)
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
5 is 5
# Out:
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
# C:\Users\dasar\AppData\Local\Temp\ipykernel_10928\4076878293.py:1: SyntaxWarning: "is" with 'int' literal. Did you mean "=="?
#   5 is 5
# True

# %%
5 is not 4
# Out:
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# <>:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
# C:\Users\dasar\AppData\Local\Temp\ipykernel_10928\3964053989.py:1: SyntaxWarning: "is not" with 'int' literal. Did you mean "!="?
#   5 is not 4
# True
